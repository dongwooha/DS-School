# %% [markdown]
# ### 1. 할인 가격
#
# 기름값을 계산하라. 많이 사면 할인을 해준다.
#
# * 처음 20갤론: 갤론 당 90센트
# * 다음 40갤로: 갤론 당 80센트
# * 나머지: 갤론 당 75센트
#
# 예를 들어 35갤론을 구입했다면, 가격은 30달러(20 * 90 + 15 * 80)

# %%
20 * 90 + 15 * 80
# Out:
# 3000

# %%
def price_cal(gallon):

    if gallon <= 20:
        price = 90 * gallon
    elif gallon <= 40:
        price = 90 * 20 + 80 * (gallon-20)
    elif gallon > 40:
        price = 90 * 20 + 80 * 20 + 75 * (gallon-40)
    
    return('The price of ', gallon, "gallon is ", price)

print(price_cal(10))
print(price_cal(40))
print(price_cal(100))
# Out:
# ('The price of ', 10, 'gallon is ', 900)
# ('The price of ', 40, 'gallon is ', 3400)
# ('The price of ', 100, 'gallon is ', 7900)

# %% [markdown]
# ### 369게임
#
# 369게임은 다음과 같습니다.
#
# 1. 1부터 시작해서 숫자를 하나씩 센다.
# 2. 숫자에 3이나, 6이나, 9가 있을 경우 박수(clap)을 친다.
# 3. 지정한 최대 숫자까지 도달하면 플고그램을 종료한다.

# %%
count = 335

for n in range(count):
    n_text = str(n)

    ## ToDo
    ## 박수를 여러번 치는 경우를 고려해서 계산해주세요.
    ## Tips: 파이썬 문자열의 count 메소드를 사용해보세요. 
    if "3" in n_text or "6" in n_text or "9" in n_text:
        
        if "3" in n_text:
            text_count = n_text.count("3")
        elif "6" in n_text:
            text_count = n_text.count("6")
        elif "9" in n_text:
            text_count = n_text.count("9")

        print(n)    
        
        for i in range(text_count):
            print("clap!")
            
    else:
        print(n)
        
    #if n == 3 or n ==6 or n == 9:
    #    print(n, "clap!")
    #else:
    #    print(n)
# Out:
# 0
# 1
# 2
# 3
# clap!
# 4
# 5
# 6
# clap!
# 7
# 8
# 9
# clap!
# 10
# 11
# 12
# 13
# clap!
# 14
# 15
# 16
# clap!
# 17
# 18
# 19
# clap!
# 20
# 21
# 22
# 23
# clap!
# 24
# 25
# 26
# clap!
# 27
# 28
# 29
# clap!
# 30
# clap!
# 31
# clap!
# 32
# clap!
# 33
# clap!
# clap!
# 34
# clap!
# 35
# clap!
# 36
# clap!
# 37
# clap!
# 38
# clap!
# 39
# clap!
# 40
# 41
# 42
# 43
# clap!
# 44
# 45
# 46
# clap!
# 47
# 48
# 49
# clap!
# 50
# 51
# 52
# 53
# clap!
# 54
# 55
# 56
# clap!
# 57
# 58
# 59
# clap!
# 60
# clap!
# 61
# clap!
# 62
# clap!
# 63
# clap!
# 64
# clap!
# 65
# clap!
# 66
# clap!
# clap!
# 67
# clap!
# 68
# clap!
# 69
# clap!
# 70
# 71
# 72
# 73
# clap!
# 74
# 75
# 76
# clap!
# 77
# 78
# 79
# clap!
# 80
# 81
# 82
# 83
# clap!
# 84
# 85
# 86
# clap!
# 87
# 88
# 89
# clap!
# 90
# clap!
# 91
# clap!
# 92
# clap!
# 93
# clap!
# 94
# clap!
# 95
# clap!
# 96
# clap!
# 97
# clap!
# 98
# clap!
# 99
# clap!
# clap!
# 100
# 101
# 102
# 103
# clap!
# 104
# 105
# 106
# clap!
# 107
# 108
# 109
# ...

# %%
str(count)
# Out:
# '14'

# %%
'3' in '13'
# Out:
# True

# %%
"3" in "33"
# Out:
# True

# %%
"33".count("3")
# Out:
# 2
